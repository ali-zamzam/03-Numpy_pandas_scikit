# %%
import pandas as pd

# %%
# https://www.data.gouv.fr/fr/datasets/liste-des-points-de-contact-du-reseau-postal-francais-horaires-equipements-et-services-associes/#_
url= "http://datanova.legroupe.laposte.fr/explore/dataset/laposte_autompre/download/?format=csv&timezone=Europe/Berlin&use_labels_for_header=true"

pd.read_csv(url, sep=";")
# Out:
#       #Identifiant_A  Identifiant_R                      Libellé_du_site  \
# 0             00015A          10320     BELIGNEUX CAMP DE LA VALBONNE BP
# 1             00001A          10040                    AMBERIEU EN BUGEY
# 2             00001A          10040                    AMBERIEU EN BUGEY
# 3             00015A          10320     BELIGNEUX CAMP DE LA VALBONNE BP
# 4             00009A          10220                          ARTEMARE BP
# ...              ...            ...                                  ...
# 23700         70178A         354680           RENNES DSI RESEAU LA POSTE
# 23701         70178A         354680           RENNES DSI RESEAU LA POSTE
# 23702         82749A         979760                ST DENIS LA SOURCE BP
# 23703         90004A         136460  MARSEILLE PROV ALPES COTE AZUR DAST
# 23704         90162A         722500                        LE MANS ADAST
#
#                              Adresse          Complément_adresse Lieu_dit  \
# ...
