# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 20)

clients = pd.read_csv("clients.csv", sep=';',  encoding='windows-1252', index_col="id")
produits = pd.read_csv("produits.csv", sep=';',  encoding='windows-1252', index_col="idproduit")
semaine1 = pd.read_csv("semaine 1.csv", sep=';',  encoding='windows-1252')
semaine2 = pd.read_csv("semaine 2.csv", sep=';',  encoding='windows-1252')

# %%
pd.merge(semaine1, clients, how='left', left_on='idclient', right_on='id')
# Out:
#      idclient  idproduit              nom     prenom  \
# 0         512          3              NaN        NaN
# 1         499          3              NaN        NaN
# 2         499         13              NaN        NaN
# 3          11          9          LOUMPRE    Jacques
# 4          24         19            DEMAY    Monique
# 5          44         12        GOURRINAT    Jpierre
# 6          34          8           WEBERT      Edith
# 7          24         19            DEMAY    Monique
# 8          23         15             PONS    Aurélie
# 9          46         14      TEILLAGORRY   Patricia
# ..        ...        ...              ...        ...
# 240        17          9            DELME    Jacques
# 241        16         12       DOCRUZEIRO  Charlette
# 242        35         10        LOSTAPLAA      Simon
# 243        35          2        LOSTAPLAA      Simon
# 244        10          1          PESENTI       Joel
# 245        48         14          GANTIER      Odile
# 246        17         19            DELME    Jacques
# 247        39         13  EPC  ATLANTIQUE        NaN
# 248        45          6      SIN CADENAS   Gregorio
# 249        18          9           CAUCHI       René
#
#                                   societe     fonction
# 0                                     NaN          NaN
# 1                                     NaN          NaN
# 2                                     NaN          NaN
# 3    MONOPRIX EXPLOIT PAR ABREVIATION MPX      manager
# 4                         ROQUETTE FRERES  admin resau
# 5                                SYNERGIE    directeur
# 6                      SOPRA STERIA GROUP      employé
# 7                         ROQUETTE FRERES  admin resau
# 8                                  DALKIA   secretaire
# 9                              CHRONOPOST    boulanger
# ..                                    ...          ...
# 240                      CASTORAMA FRANCE    directeur
# 241                               L'OREAL      employé
# 242                  H&M HENNES & MAURITZ    directeur
# 243                  H&M HENNES & MAURITZ    directeur
# 244             METRO CASH & CARRY FRANCE    boulanger
# 245                            CGI FRANCE  developpeur
# 246                      CASTORAMA FRANCE    directeur
# 247                                  CRIT  developpeur
# 248                              SYNERGIE      medecin
# 249                   MEUBLES IKEA FRANCE      medecin
#
# [250 rows x 6 columns]
