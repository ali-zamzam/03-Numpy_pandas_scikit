# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 10)

# %%
produits = pd.read_excel("composition-nutritionnelle.xls", index_col=[0],usecols=[6,7,12,13,15,16,17,18])

# %%
# faisons une copie de notre DataFrame
copieProd = produits.copy()

# %%
copieProd.head()
# Out:
#                                                  alim_nom_fr Eau (g/100g)  \
# alim_code
# 25600                           Céleri rémoulade, préemballé         78,5
# 25601        Salade de thon et légumes, appertisée, égouttée         76,5
# 25602      Salade composée avec viande ou poisson, appert...         76,7
# 25605                                Champignon à la grecque         84,6
# 25606                       Salade de pommes de terre maison           76
#
#           Protéines (g/100g) Glucides (g/100g) Lipides (g/100g)  \
# alim_code
# 25600                   1,12              4,19             12,8
# 25601                   9,15              7,74              4,7
# 25602                   8,06               6,4              5,3
# 25605                   2,08              3,95             3,55
# 25606                   2,68               9,9              8,2
#
#           Sucres (g/100g) Amidon (g/100g)
# alim_code
# 25600                2,38             1,3
# 25601                3,08             4,1
# 25602                 1,9             3,3
# 25605                2,38            0,28
# 25606                   -               -

# %%
copieProd['Eau (g/100g)']=copieProd['Eau (g/100g)']+" gr"

# %%
copieProd.head()
# Out:
#                                                  alim_nom_fr Eau (g/100g)  \
# alim_code
# 25600                           Céleri rémoulade, préemballé      78,5 gr
# 25601        Salade de thon et légumes, appertisée, égouttée      76,5 gr
# 25602      Salade composée avec viande ou poisson, appert...      76,7 gr
# 25605                                Champignon à la grecque      84,6 gr
# 25606                       Salade de pommes de terre maison        76 gr
#
#           Protéines (g/100g) Glucides (g/100g) Lipides (g/100g)  \
# alim_code
# 25600                   1,12              4,19             12,8
# 25601                   9,15              7,74              4,7
# 25602                   8,06               6,4              5,3
# 25605                   2,08              3,95             3,55
# 25606                   2,68               9,9              8,2
#
#           Sucres (g/100g) Amidon (g/100g)
# alim_code
# 25600                2,38             1,3
# 25601                3,08             4,1
# 25602                 1,9             3,3
# 25605                2,38            0,28
# 25606                   -               -
