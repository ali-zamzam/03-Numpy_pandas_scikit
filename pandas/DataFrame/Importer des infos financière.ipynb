# %%
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like

import pandas_datareader.data as web
import datetime as dt

# %%
action= '^DJI'
action="TSLA"
source = 'stooq'
source ="morningstar"
depuis = "2015-01-01"
jusqua = "2018-08-21"
depuis = dt.date(2015, 2, 9)
jusqua =  dt.date(2018, 8, 18)

#df = web.DataReader(name=action,data_source=source,start=depuis,end=jusqua)

#df = web.DataReader(name=action,data_source='google',start=depuis,end=jusqua)
#df2 = web.DataReader("google",source,depuis,jusqua)
#action=web.DataReader('USD000UTSTOM', 'moex', start=depuis, end=jusqua)
action=web.DataReader('^DJI', 'stooq')

# %%
action.index
# Out:
# DatetimeIndex(['2018-08-20', '2018-08-17', '2018-08-16', '2018-08-15',
#                '2018-08-14', '2018-08-13', '2018-08-10', '2018-08-09',
#                '2018-08-08', '2018-08-07',
#                ...
#                '1896-06-09', '1896-06-08', '1896-06-05', '1896-06-04',
#                '1896-06-03', '1896-06-02', '1896-06-01', '1896-05-29',
#                '1896-05-28', '1896-05-27'],
#               dtype='datetime64[ns]', name='Date', length=31694, freq=None)

# %%
action
# Out:
#                 Open      High       Low     Close       Volume
# Date
# 2018-08-20  25727.70  25790.17  25716.41  25758.69          NaN
# 2018-08-17  25550.80  25728.16  25521.66  25669.32   81028248.0
# 2018-08-16  25294.97  25607.34  25294.97  25558.73   85374528.0
# 2018-08-15  25235.37  25235.37  24965.77  25162.41   79783352.0
# 2018-08-14  25215.69  25339.51  25201.87  25299.92   57509176.0
# 2018-08-13  25327.19  25381.39  25153.93  25187.70   64198680.0
# 2018-08-10  25401.19  25401.19  25222.88  25313.14   60954752.0
# 2018-08-09  25589.79  25613.31  25492.69  25509.23   59553920.0
# 2018-08-08  25615.72  25634.11  25557.48  25583.75   60567820.0
# 2018-08-07  25551.65  25692.72  25551.65  25628.91   64961976.0
# 2018-08-06  25437.43  25540.02  25381.38  25502.18   66822708.0
# 2018-08-03  25360.37  25467.90  25325.17  25462.58   67528456.0
# 2018-08-02  25256.45  25360.48  25120.07  25326.16   81618136.0
# 2018-08-01  25461.63  25488.80  25278.32  25333.82   82420312.0
# ...

# %%
action.sort_index(inplace=True)

# %%
action.loc["2018-01-01":"2018-08-01"]
# Out:
#                 Open      High       Low     Close       Volume
# Date
# 2018-01-02  24809.35  24864.19  24741.70  24824.01   93837856.0
# 2018-01-03  24850.45  24941.92  24825.55  24922.68  113120472.0
# 2018-01-04  24964.86  25105.96  24963.27  25075.13  101492432.0
# 2018-01-05  25114.92  25299.79  25112.01  25295.87   99171640.0
# 2018-01-08  25308.40  25311.99  25235.41  25283.00   97611920.0
# 2018-01-09  25312.05  25439.78  25308.41  25385.80   88515640.0
# 2018-01-10  25348.13  25404.92  25256.99  25369.13   88364144.0
# 2018-01-11  25398.60  25575.42  25396.19  25574.73   90362032.0
# 2018-01-12  25638.39  25810.43  25633.08  25803.19  103878720.0
# 2018-01-16  25987.62  26086.12  25702.99  25792.86  171084224.0
# 2018-01-17  25910.78  26130.45  25865.02  26115.65  133700112.0
# 2018-01-18  26149.55  26153.42  25947.32  26017.81  122449616.0
# 2018-01-19  25987.35  26071.72  25942.83  26071.72  171541424.0
# 2018-01-22  26025.32  26215.23  25974.65  26214.60  126357768.0
# ...
