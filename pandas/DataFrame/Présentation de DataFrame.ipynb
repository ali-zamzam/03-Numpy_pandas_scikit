# %% [markdown]
# Un DataFrame est une structure de données bidimensionnelle, c'est-à-dire que les données sont alignées de façon tabulaire en lignes et en colonnes.
#
# Caractéristiques de DataFrame
# * Les colonnes peuvent être de types différents
# * Taille - Mutable
# * Axes étiquetés (lignes et colonnes)
# * Peut effectuer des opérations arithmétiques sur les lignes et les colonnes.
#
# On peut toute proportion gardée comparer un DataFrame à une feuille excel avec des lignes et des colonnes.
# Dans ce chapitre, nous allons examiner le DataFrame et la façon dont nous pouvons manipuler à la fois le DataFrame et les données qu'il représente pour construire une base pour réaliser des données interactives.
#
# Avant de commencer, récapitulons brièvement ce que sont les DataFrames.
#
# Ceux qui sont familiers avec R savent que le dataFrame est un moyen de stocker les données dans des grilles rectangulaires qui peuvent être facilement visualisées. Chaque ligne de ces grilles correspond aux mesures ou valeurs d'une instance, tandis que chaque colonne est un vecteur contenant des données pour une variable spécifique. Cela signifie que les lignes d'un bloc de données n'ont pas besoin de contenir, mais peuvent contenir, le même type de valeurs : elles peuvent être numériques, caractères, logiques, etc.
#
# Maintenant, les DataFrames en Python sont très similaires : ils viennent avec la bibliothèque Pandas, et ils sont définis comme des structures de données bidimensionnelles étiquetées avec des colonnes de types potentiellement différents.
#
# En général, on pourrait dire que le DataFrame de Pandas se compose de trois composantes principales : les données, l'index et les colonnes.
#
#     Tout d'abord, le DataFrame peut contenir des données qui sont :
#
#     a Pandas DataFrame
#     une série Pandas : un tableau unidimensionnel étiqueté capable de contenir n'importe quel type de données avec des étiquettes d'axe ou d'index. Un exemple d'objet Série est une colonne d'un DataFrame.
#     un NumPy ndarray, qui peut être un enregistrement ou structuré.
#     un ndarray bidimensionnel
#     des dictionnaires de ndarray unidimensionnels, des listes, des dictionnaires ou des séries.
#
#
# Notez la différence entre np.ndarray et np.array() . Le premier est un type de données réelles, tandis que le second est une fonction permettant de créer des tableaux à partir d'autres structures de données.

# %% [markdown]
# ![pr%C3%A9sentation%20dataframe.png](attachment:pr%C3%A9sentation%20dataframe.png)
