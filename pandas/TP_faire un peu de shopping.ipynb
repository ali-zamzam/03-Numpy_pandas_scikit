# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <b>Découverte du data set</b>

# %%
data = pd.read_csv('Datafiniti_Womens_Shoes.csv')
data
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 0     AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1     AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2     AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3     AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4     AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
# ...                    ...                   ...                   ...   ...
# 9995  AWKcCm-RHh53nbDRIh1_  2018-04-06T17:33:30Z  2018-04-06T21:02:04Z   NaN
# 9996  AWKcEq-dHh53nbDRIiES  2018-04-06T17:33:29Z  2018-04-06T21:02:04Z   NaN
# 9997  AWKb5jmLYSSHbkXwyzBA  2018-04-06T16:46:35Z  2018-04-06T21:02:01Z   NaN
# 9998  AWKcEIInYSSHbkXwy0SA  2018-04-06T17:33:30Z  2018-04-06T21:01:53Z   NaN
# 9999  AWKb6PiKYSSHbkXwyzP-  2018-04-06T16:45:52Z  2018-04-06T21:01:50Z   NaN
#
# ...

# %%
data.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
data.head(5)
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
data["id"]
# Out:
# 0       AVpfEf_hLJeJML431ueH
# 1       AVpi74XfLJeJML43qZAc
# 2       AVpi74XfLJeJML43qZAc
# 3       AVpjXyCc1cnluZ0-V-Gj
# 4       AVphGKLPilAPnD_x1Nrm
#                 ...
# 9995    AWKcCm-RHh53nbDRIh1_
# 9996    AWKcEq-dHh53nbDRIiES
# 9997    AWKb5jmLYSSHbkXwyzBA
# 9998    AWKcEIInYSSHbkXwy0SA
# 9999    AWKb6PiKYSSHbkXwyzP-
# Name: id, Length: 10000, dtype: object

# %%
data_copie = data3

# %%
data3 = data["dateUpdated"]

# %%
pd.set_option("display.max_columns",34)

pd.get_option("display.max_columns")
# Out:
# 34

# %%
data.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
shoesLight = data[{'id','name','dateUpdated','colors','prices.amountMax','prices.amountMin','prices.merchant'}]

# %%
shoesLight.head(5)
# Out:
#                            colors  \
# 0  Silver,Cream Watercolor Floral
# 1                            Grey
# 2                            Grey
# 3                           Black
# 4                            Grey
#
#                                                 name  prices.amountMin  \
# 0  Naturalizer Danya Women N/S Open Toe Synthetic...             55.99
# 1                MUK LUKS Womens Jane Suede Moccasin             35.25
# 2                MUK LUKS Womens Jane Suede Moccasin             35.25
# 3           MUK LUKS Womens Dawn Suede Scuff Slipper             24.75
# 4           MUK LUKS Womens Dawn Suede Scuff Slipper             30.39
#
#             dateUpdated                    id  prices.amountMax  \
# 0  2018-01-29T04:38:43Z  AVpfEf_hLJeJML431ueH             55.99
# 1  2018-01-03T05:21:54Z  AVpi74XfLJeJML43qZAc             47.00
# 2  2018-01-03T05:21:54Z  AVpi74XfLJeJML43qZAc             35.25
# 3  2018-01-04T11:52:35Z  AVpjXyCc1cnluZ0-V-Gj             24.75
# ...

# %% [markdown]
# <b>data cleaning</b>

# %%
data.dtypes
# Out:
# id                      object
# dateAdded               object
# dateUpdated             object
# asins                   object
# brand                   object
# categories              object
# primaryCategories       object
# colors                  object
# dimension               object
# ean                    float64
# imageURLs               object
# keys                    object
# manufacturer            object
# manufacturerNumber      object
# name                    object
# prices.amountMax       float64
# prices.amountMin       float64
# prices.availability     object
# prices.color            object
# prices.condition        object
# prices.currency         object
# prices.dateAdded        object
# prices.dateSeen         object
# prices.isSale             bool
# prices.merchant         object
# prices.offer            object
# prices.returnPolicy    float64
# prices.shipping         object
# prices.size             object
# prices.sourceURLs       object
# ...

# %%
shoesLight.dtypes
# Out:
# colors               object
# name                 object
# prices.amountMin    float64
# dateUpdated          object
# id                   object
# prices.amountMax    float64
# prices.merchant      object
# dtype: object

# %% [markdown]
# <b> C'est possible de changer le type d'un colonne en utilisant la methode (astype)
#     ---------------->  par exemple : data[""] = data[" "].astype("int")</b>

# %%
data.isnull()
# Out:
#          id  dateAdded  dateUpdated  asins  brand  categories  \
# 0     False      False        False   True  False       False
# 1     False      False        False   True  False       False
# 2     False      False        False   True  False       False
# 3     False      False        False   True  False       False
# 4     False      False        False   True  False       False
# ...     ...        ...          ...    ...    ...         ...
# 9995  False      False        False   True  False       False
# 9996  False      False        False   True  False       False
# 9997  False      False        False   True  False       False
# 9998  False      False        False   True  False       False
# 9999  False      False        False   True  False       False
#
#       primaryCategories  colors  dimension    ean  imageURLs   keys  \
# 0                 False   False       True   True      False  False
# 1                 False   False       True  False      False  False
# ...

# %%
shoesLight.isnull().sum()/len(shoesLight)
# Out:
# colors              0.7369
# name                0.0000
# prices.amountMin    0.0000
# dateUpdated         0.0000
# id                  0.0000
# prices.amountMax    0.0000
# prices.merchant     0.9565
# dtype: float64

# %%
data_copie
# Out:
# 0       2018-01-29T04:38:43Z
# 1       2018-01-03T05:21:54Z
# 2       2018-01-03T05:21:54Z
# 3       2018-01-04T11:52:35Z
# 4       2018-01-18T03:55:18Z
#                 ...
# 9995    2018-04-06T21:02:04Z
# 9996    2018-04-06T21:02:04Z
# 9997    2018-04-06T21:02:01Z
# 9998    2018-04-06T21:01:53Z
# 9999    2018-04-06T21:01:50Z
# Name: dateUpdated, Length: 10000, dtype: object

# %%
pd.to_datetime("2018-08-29")
# Out:
# Timestamp('2018-08-29 00:00:00')

# %%
pd.to_datetime(data_copie)
# Out:
# 0      2018-01-29 04:38:43+00:00
# 1      2018-01-03 05:21:54+00:00
# 2      2018-01-03 05:21:54+00:00
# 3      2018-01-04 11:52:35+00:00
# 4      2018-01-18 03:55:18+00:00
#                   ...
# 9995   2018-04-06 21:02:04+00:00
# 9996   2018-04-06 21:02:04+00:00
# 9997   2018-04-06 21:02:01+00:00
# 9998   2018-04-06 21:01:53+00:00
# 9999   2018-04-06 21:01:50+00:00
# Name: dateUpdated, Length: 10000, dtype: datetime64[ns, UTC]

# %% [markdown]
# <b>features modeling</b>

# %%
shoesLight1 = shoesLight['prices.amountMax']
shoesLight2 = shoesLight['prices.amountMin']

# %%
shoesLight['prices.amountAverage'] = (shoesLight['prices.amountMax'] + shoesLight['prices.amountMin'])/2
# Out:
# <ipython-input-198-9a55407d2460>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shoesLight['prices.amountAverage'] = (shoesLight['prices.amountMax'] + shoesLight['prices.amountMin'])/2

# %%
shoesLight
# Out:
#                                    colors  \
# 0          Silver,Cream Watercolor Floral
# 1                                    Grey
# 2                                    Grey
# 3                                   Black
# 4                                    Grey
# ...                                   ...
# 9995                Silver/Pistachio/Pink
# 9996             Indigo Blue/Silver/Prune
# 9997                                Mauve
# 9998  Armory Blue/Armory Navy-Cirrus Blue
# 9999                                Black
#
#                                                    name  prices.amountMin  \
# 0     Naturalizer Danya Women N/S Open Toe Synthetic...             55.99
# 1                   MUK LUKS Womens Jane Suede Moccasin             35.25
# 2                   MUK LUKS Womens Jane Suede Moccasin             35.25
# 3              MUK LUKS Womens Dawn Suede Scuff Slipper             24.75
# 4              MUK LUKS Womens Dawn Suede Scuff Slipper             30.39
# ...

# %%
shoesLight.head()
# Out:
#                            colors  \
# 0  Silver,Cream Watercolor Floral
# 1                            Grey
# 2                            Grey
# 3                           Black
# 4                            Grey
#
#                                                 name  prices.amountMin  \
# 0  Naturalizer Danya Women N/S Open Toe Synthetic...             55.99
# 1                MUK LUKS Womens Jane Suede Moccasin             35.25
# 2                MUK LUKS Womens Jane Suede Moccasin             35.25
# 3           MUK LUKS Womens Dawn Suede Scuff Slipper             24.75
# 4           MUK LUKS Womens Dawn Suede Scuff Slipper             30.39
#
#             dateUpdated                    id  prices.amountMax  \
# 0  2018-01-29T04:38:43Z  AVpfEf_hLJeJML431ueH             55.99
# 1  2018-01-03T05:21:54Z  AVpi74XfLJeJML43qZAc             47.00
# 2  2018-01-03T05:21:54Z  AVpi74XfLJeJML43qZAc             35.25
# 3  2018-01-04T11:52:35Z  AVpjXyCc1cnluZ0-V-Gj             24.75
# ...

# %%
data = pd.read_csv('Datafiniti_Womens_Shoes.csv')
data['dayOfweekUpdated'] = data['dateUpdate']dt.weekday()
# Out:
#   File "<ipython-input-204-594c804c63b1>", line 2
#     data['dayOfweekUpdated'] = data['dateUpdate']dt.weekday()
#                                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# <b> data analyse</b>

# %%
shoesLight['prices.amountAverage'].describe()
# Out:
# count    10000.000000
# mean        60.177377
# std         18.786193
# min          5.375000
# 25%         49.990000
# 50%         56.875000
# 75%         67.490000
# max        359.950000
# Name: prices.amountAverage, dtype: float64

# %%
data2 = pd.read_csv('Datafiniti_Womens_Shoes.csv')
data2.head(5)
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
data2.dtypes
# Out:
# id                      object
# dateAdded               object
# dateUpdated             object
# asins                   object
# brand                   object
# categories              object
# primaryCategories       object
# colors                  object
# dimension               object
# ean                    float64
# imageURLs               object
# keys                    object
# manufacturer            object
# manufacturerNumber      object
# name                    object
# prices.amountMax       float64
# prices.amountMin       float64
# prices.availability     object
# prices.color            object
# prices.condition        object
# prices.currency         object
# prices.dateAdded        object
# prices.dateSeen         object
# prices.isSale             bool
# prices.merchant         object
# prices.offer            object
# prices.returnPolicy    float64
# prices.shipping         object
# prices.size             object
# prices.sourceURLs       object
# ...

# %%
df = data2.groupby('brand')
df

# %%
df.mean('brand')
# Out:
#                                 ean  prices.amountMax  prices.amountMin  \
# brand
# 2 lips too                      NaN         67.320526         53.400526
# Adidas                          NaN        135.664286         97.057619
# Adidas Outdoor                  NaN        107.950000        107.950000
# Altra                           NaN        129.950000        111.669048
# Arc'teryx                       NaN        170.000000        130.333333
# ...                             ...               ...               ...
# style charles by charles david  NaN         88.853556         60.382552
# sugar                           NaN         49.990000         34.458750
# under armour                    NaN         79.990000         67.262727
# unionbay                        NaN         47.990000         33.799091
# vans                            NaN         60.615000         55.729583
#
#                                 prices.isSale  prices.returnPolicy
# brand
# ...

# %%
df2 = data.sort_values(by=['brand','prices.amountMax','prices.amountMin'])
df2.head(5)
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 8626  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8628  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8633  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8635  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8624  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
#
#            brand                           categories primaryCategories  \
# 8626  2 lips too  Womens,Shoes,Pumps,Heels,2 Lips Too             Shoes
# 8628  2 lips too  Womens,Shoes,Pumps,Heels,2 Lips Too             Shoes
# 8633  2 lips too  Womens,Shoes,Pumps,Heels,2 Lips Too             Shoes
# 8635  2 lips too  Womens,Shoes,Pumps,Heels,2 Lips Too             Shoes
# 8624  2 lips too  Womens,Shoes,Pumps,Heels,2 Lips Too             Shoes
#
# ...

# %%
data["dateUpdated"].value_counts()
# Out:
# 2018-02-01T07:33:40Z    235
# 2018-02-01T07:36:18Z    231
# 2018-02-01T07:34:21Z    210
# 2018-01-29T04:30:01Z    187
# 2018-02-01T07:36:45Z    159
#                        ...
# 2018-01-28T10:21:12Z      1
# 2018-04-10T19:28:24Z      1
# 2018-01-19T08:33:34Z      1
# 2018-01-03T05:22:08Z      1
# 2018-01-28T09:00:45Z      1
# Name: dateUpdated, Length: 495, dtype: int64

# %%
ShoesLight['prices.amountAverage'][
(ShoesLight['dateUpdated_week'] == 3) & (ShoesLight['brand'] == 'easy street')
].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-7c2936d9eb73> in <module>
# ----> 1 ShoesLight['prices.amountAverage'][
#       2 (ShoesLight['dateUpdated_week'] == 3) & (ShoesLight['brand'] == 'easy street')
#       3 ].mean()
#
# NameError: name 'ShoesLight' is not defined
