# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# url = 'https://public.opendatasoft.com/explore/dataset/population-francaise-communes/download/?format=csv&timezone=Europe/Berlin&lang=fr&use_labels_for_header=true&csv_separator=%3B'
# data = pd.read_csv(url,sep=";")
# data.head(5)

# %%
data1 = pd.read_csv('Departements.csv', sep=';')
data1.head(5)
# Out:
#   CODDEP                      DEP  NBARR  NBCAN  NBCOM    PMUN    PTOT  \
# 0     01                      Ain      4   23.0    393  643350  659180
# 1     02                    Aisne      5   21.0    800  534490  546527
# 2     03                   Allier      3   19.0    317  337988  347035
# 3     04  Alpes-de-Haute-Provence      4   15.0    198  163915  168381
# 4     05             Hautes-Alpes      2   15.0    162  141284  145883
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
data1.columns=['Code département','département','nb arrondissement',' nb canton','nb commune','Population municipale','Population totale','null']
data1
# Out:
#    Code département              département  nb arrondissement   nb canton  \
# 0                01                      Ain                  4        23.0
# 1                02                    Aisne                  5        21.0
# 2                03                   Allier                  3        19.0
# 3                04  Alpes-de-Haute-Provence                  4        15.0
# 4                05             Hautes-Alpes                  2        15.0
# ..              ...                      ...                ...         ...
# 95               95               Val-d'Oise                  3        21.0
# 96              971               Guadeloupe                  2        21.0
# 97              972               Martinique                  4         NaN
# 98              973                   Guyane                  2         NaN
# 99              974               La Réunion                  4        25.0
#
#     nb commune  Population municipale  Population totale  null
# 0          393                 643350             659180   NaN
# 1          800                 534490             546527   NaN
# 2          317                 337988             347035   NaN
# 3          198                 163915             168381   NaN
# 4          162                 141284             145883   NaN
# ..         ...                    ...                ...   ...
# 95         184                1228618            1239262   NaN
# 96          32                 390253             396153   NaN
# 97          34                 372594             377711   NaN
# 98          22                 268700             271124   NaN
# 99          24                 853659             863063   NaN
#
# [100 rows x 8 columns]

# %%
data11= data1.copy()
data11.head(1)
# Out:
#   Code département département  nb arrondissement   nb canton  nb commune  \
# 0               01         Ain                  4        23.0         393
#
#    Population municipale  Population totale  null
# 0                 643350             659180   NaN

# %%
data11.drop(data11.loc[:,"nb arrondissement":"Population municipale"],1,inplace=True)
data11
# Out:
#    Code département              département  Population totale  null
# 0                01                      Ain             659180   NaN
# 1                02                    Aisne             546527   NaN
# 2                03                   Allier             347035   NaN
# 3                04  Alpes-de-Haute-Provence             168381   NaN
# 4                05             Hautes-Alpes             145883   NaN
# ..              ...                      ...                ...   ...
# 95               95               Val-d'Oise            1239262   NaN
# 96              971               Guadeloupe             396153   NaN
# 97              972               Martinique             377711   NaN
# 98              973                   Guyane             271124   NaN
# 99              974               La Réunion             863063   NaN
#
# [100 rows x 4 columns]

# %%
del data11["null"]
data11
# Out:
#    Code département              département  Population totale
# 0                01                      Ain             659180
# 1                02                    Aisne             546527
# 2                03                   Allier             347035
# 3                04  Alpes-de-Haute-Provence             168381
# 4                05             Hautes-Alpes             145883
# ..              ...                      ...                ...
# 95               95               Val-d'Oise            1239262
# 96              971               Guadeloupe             396153
# 97              972               Martinique             377711
# 98              973                   Guyane             271124
# 99              974               La Réunion             863063
#
# [100 rows x 3 columns]

# %%
data_1_n = data11.copy()
data_1_n
# Out:
#    Code département              département  Population totale
# 0                01                      Ain             659180
# 1                02                    Aisne             546527
# 2                03                   Allier             347035
# 3                04  Alpes-de-Haute-Provence             168381
# 4                05             Hautes-Alpes             145883
# ..              ...                      ...                ...
# 95               95               Val-d'Oise            1239262
# 96              971               Guadeloupe             396153
# 97              972               Martinique             377711
# 98              973                   Guyane             271124
# 99              974               La Réunion             863063
#
# [100 rows x 3 columns]

# %%
data_1_n.sort_values("Code département",ascending=0)
# Out:
#    Code département              département  Population totale
# 99              974               La Réunion             863063
# 98              973                   Guyane             271124
# 97              972               Martinique             377711
# 96              971               Guadeloupe             396153
# 95               95               Val-d'Oise            1239262
# ..              ...                      ...                ...
# 4                05             Hautes-Alpes             145883
# 3                04  Alpes-de-Haute-Provence             168381
# 2                03                   Allier             347035
# 1                02                    Aisne             546527
# 0                01                      Ain             659180
#
# [100 rows x 3 columns]

# %%
data_1_n["Population totale"].sum()
# Out:
# 67761092

# %% [markdown]
# <h1>--------------------------------------------------------------------------------------------------------</h1>

# %%
data2 = pd.read_csv('population-francaise-communes.csv', sep=';')
data2.head(1)
# Out:
#    Code région Nom de la région Code département  \
# 0         82.0      Rhône-Alpes               26
#
#    Code arrondissement départemental  Code canton  Code commune  \
# 0                                1.0          9.0         246.0
#
#       Nom de la commune  Population municipale  Population comptée à part  \
# 0  Ponet-et-Saint-Auban                  121.0                        3.0
#
#    Population totale  ...  Code INSEE (commune ou arrondissement)  \
# 0              124.0  ...                                   26246
#
#    Superficie de la commune   Statut  Code INSEE de la commune  \
# 0                      13.4  Commune                     26246
#
#   Nom de la commune IGN Nom du département IGN Nom de la région.1 Code EPCI  \
# 0  Ponet-et-Saint-Auban                  DROME        Rhône-Alpes       NaN
#
#   Code EPCI.1 EPCI
# 0         NaN  NaN
#
# [1 rows x 22 columns]

# %%
data2[["Code région","Nom de la région","Code département","Nom de la commune","Population totale"]]
# Out:
#         Code région  Nom de la région Code département      Nom de la commune  \
# 0              82.0       Rhône-Alpes               26   Ponet-et-Saint-Auban
# 1              82.0       Rhône-Alpes               26       Rochefort-Samson
# 2              82.0       Rhône-Alpes               26          Rochefourchat
# 3              82.0       Rhône-Alpes               26  Saint-Dizier-en-Diois
# 4              82.0       Rhône-Alpes               26            Saint-Roman
# ...             ...               ...              ...                    ...
# 400637         44.0         GRAND EST               52               Voncourt
# 400638         52.0  Pays de la Loire               53               Ampoigné
# 400639         52.0  PAYS DE LA LOIRE               53                 Bierné
# 400640         52.0  Pays de la Loire               53                 Commer
# 400641         52.0  PAYS DE LA LOIRE               53               Louvigné
#
#         Population totale
# 0                   124.0
# 1                   931.0
# 2                     1.0
# 3                    37.0
# 4                   161.0
# ...                   ...
# 400637               18.0
# 400638              575.0
# 400639              691.0
# 400640             1252.0
# 400641             1129.0
#
# [400642 rows x 5 columns]

# %%
data3 = data2.copy()
data3.head(1)
# Out:
#    Code région Nom de la région Code département  \
# 0         82.0      Rhône-Alpes               26
#
#    Code arrondissement départemental  Code canton  Code commune  \
# 0                                1.0          9.0         246.0
#
#       Nom de la commune  Population municipale  Population comptée à part  \
# 0  Ponet-et-Saint-Auban                  121.0                        3.0
#
#    Population totale  ...  Code INSEE (commune ou arrondissement)  \
# 0              124.0  ...                                   26246
#
#    Superficie de la commune   Statut  Code INSEE de la commune  \
# 0                      13.4  Commune                     26246
#
#   Nom de la commune IGN Nom du département IGN Nom de la région.1 Code EPCI  \
# 0  Ponet-et-Saint-Auban                  DROME        Rhône-Alpes       NaN
#
#   Code EPCI.1 EPCI
# 0         NaN  NaN
#
# [1 rows x 22 columns]

# %%
# data_1 = data3.drop(labels=iloc["Code arrondissement départemental", "Code canton", "Code commune","Population comptée à part","Population municipale"], axis='columns')
# data_1
# data_1 = data3.drop(labels=iloc[2:5])
# data_1
# data3.drop(data3.iloc[:,3:5],1,inplace=True)
data3.drop(data3.loc[:,"Code arrondissement départemental":"Code commune"],1,inplace=True)

# %%
data3.head(1)
# Out:
#    Code région Nom de la région Code département     Nom de la commune  \
# 0         82.0      Rhône-Alpes               26  Ponet-et-Saint-Auban
#
#    Population municipale  Population comptée à part  Population totale  \
# 0                  121.0                        3.0              124.0
#
#    Année recensement  Année utilisation  \
# 0               2006               2009
#
#   Code INSEE (commune ou arrondissement)  Superficie de la commune   Statut  \
# 0                                  26246                      13.4  Commune
#
#   Code INSEE de la commune Nom de la commune IGN Nom du département IGN  \
# 0                    26246  Ponet-et-Saint-Auban                  DROME
#
#   Nom de la région.1 Code EPCI Code EPCI.1 EPCI
# 0        Rhône-Alpes       NaN         NaN  NaN

# %%
data_n = data3.copy()
data_n.head(1)
# Out:
#    Code région Nom de la région Code département     Nom de la commune  \
# 0         82.0      Rhône-Alpes               26  Ponet-et-Saint-Auban
#
#    Population municipale  Population comptée à part  Population totale  \
# 0                  121.0                        3.0              124.0
#
#    Année recensement  Année utilisation  \
# 0               2006               2009
#
#   Code INSEE (commune ou arrondissement)  Superficie de la commune   Statut  \
# 0                                  26246                      13.4  Commune
#
#   Code INSEE de la commune Nom de la commune IGN Nom du département IGN  \
# 0                    26246  Ponet-et-Saint-Auban                  DROME
#
#   Nom de la région.1 Code EPCI Code EPCI.1 EPCI
# 0        Rhône-Alpes       NaN         NaN  NaN

# %%
data_n.drop(data3.loc[:,"Année recensement":"EPCI"],1,inplace=True)

# %%
data_n.head(1)
# Out:
#    Code région Nom de la région Code département     Nom de la commune  \
# 0         82.0      Rhône-Alpes               26  Ponet-et-Saint-Auban
#
#    Population municipale  Population comptée à part  Population totale
# 0                  121.0                        3.0              124.0

# %%
data_n.drop(data_n.loc[:,"Population municipale":"Population comptée à part"],1,inplace=True)
data_n.head(1)
# Out:
#    Code région Nom de la région Code département     Nom de la commune  \
# 0         82.0      Rhône-Alpes               26  Ponet-et-Saint-Auban
#
#    Population totale
# 0              124.0

# %%
data_ne = data_n.copy()
data_ne.head(1)
# Out:
#    Code région Nom de la région Code département     Nom de la commune  \
# 0         82.0      Rhône-Alpes               26  Ponet-et-Saint-Auban
#
#    Population totale
# 0              124.0

# %%
data_ne
# Out:
#         Code région  Nom de la région Code département      Nom de la commune  \
# 0              82.0       Rhône-Alpes               26   Ponet-et-Saint-Auban
# 1              82.0       Rhône-Alpes               26       Rochefort-Samson
# 2              82.0       Rhône-Alpes               26          Rochefourchat
# 3              82.0       Rhône-Alpes               26  Saint-Dizier-en-Diois
# 4              82.0       Rhône-Alpes               26            Saint-Roman
# ...             ...               ...              ...                    ...
# 400637         44.0         GRAND EST               52               Voncourt
# 400638         52.0  Pays de la Loire               53               Ampoigné
# 400639         52.0  PAYS DE LA LOIRE               53                 Bierné
# 400640         52.0  Pays de la Loire               53                 Commer
# 400641         52.0  PAYS DE LA LOIRE               53               Louvigné
#
#         Population totale
# 0                   124.0
# 1                   931.0
# 2                     1.0
# 3                    37.0
# 4                   161.0
# ...                   ...
# 400637               18.0
# 400638              575.0
# 400639              691.0
# 400640             1252.0
# 400641             1129.0
#
# [400642 rows x 5 columns]

# %%
data_ne.isnull()
# Out:
#         Code région  Nom de la région  Code département  Nom de la commune  \
# 0             False             False             False              False
# 1             False             False             False              False
# 2             False             False             False              False
# 3             False             False             False              False
# 4             False             False             False              False
# ...             ...               ...               ...                ...
# 400637        False             False             False              False
# 400638        False             False             False              False
# 400639        False             False             False              False
# 400640        False             False             False              False
# 400641        False             False             False              False
#
#         Population totale
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 400637              False
# 400638              False
# 400639              False
# 400640              False
# 400641              False
#
# [400642 rows x 5 columns]

# %%
data_ne.isnull().value_counts()
# Out:
# Code région  Nom de la région  Code département  Nom de la commune  Population totale
# False        False             False             False              False                400633
# True         True              True              True               True                      9
# dtype: int64

# %%
data_new = data_ne.fillna(0)
data_new
# Out:
#         Code région  Nom de la région Code département      Nom de la commune  \
# 0              82.0       Rhône-Alpes               26   Ponet-et-Saint-Auban
# 1              82.0       Rhône-Alpes               26       Rochefort-Samson
# 2              82.0       Rhône-Alpes               26          Rochefourchat
# 3              82.0       Rhône-Alpes               26  Saint-Dizier-en-Diois
# 4              82.0       Rhône-Alpes               26            Saint-Roman
# ...             ...               ...              ...                    ...
# 400637         44.0         GRAND EST               52               Voncourt
# 400638         52.0  Pays de la Loire               53               Ampoigné
# 400639         52.0  PAYS DE LA LOIRE               53                 Bierné
# 400640         52.0  Pays de la Loire               53                 Commer
# 400641         52.0  PAYS DE LA LOIRE               53               Louvigné
#
#         Population totale
# 0                   124.0
# 1                   931.0
# 2                     1.0
# 3                    37.0
# 4                   161.0
# ...                   ...
# 400637               18.0
# 400638              575.0
# 400639              691.0
# 400640             1252.0
# 400641             1129.0
#
# [400642 rows x 5 columns]

# %%
data_new.isnull().value_counts()
# Out:
# Code région  Nom de la région  Code département  Nom de la commune  Population totale
# False        False             False             False              False                400642
# dtype: int64

# %%
data_new.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 400637     True
# 400638     True
# 400639     True
# 400640    False
# 400641     True
# Length: 400642, dtype: bool

# %%
data_new1 = data_new.drop_duplicates(['Nom de la commune'])
data_new1
# Out:
#         Code région      Nom de la région Code département  \
# 0              82.0           Rhône-Alpes               26
# 1              82.0           Rhône-Alpes               26
# 2              82.0           Rhône-Alpes               26
# 3              82.0           Rhône-Alpes               26
# 4              82.0           Rhône-Alpes               26
# ...             ...                   ...              ...
# 380115         26.0             Bourgogne               21
# 382239         84.0  AUVERGNE-RHONE-ALPES               74
# 391306         24.0                Centre               28
# 398155         11.0         ILE-DE-FRANCE               77
# 400517         52.0      Pays de la Loire               44
#
#                  Nom de la commune  Population totale
# 0             Ponet-et-Saint-Auban              124.0
# 1                 Rochefort-Samson              931.0
# 2                    Rochefourchat                1.0
# 3            Saint-Dizier-en-Diois               37.0
# 4                      Saint-Roman              161.0
# ...                            ...                ...
# 380115  Saint-Germain-Source-Seine               28.0
# 382239                     Sevrier             4404.0
# 391306   Bleury - Saint-Symphorien             1366.0
# 398155      Moret Loing et Orvanne             7782.0
# 400517                   Bonnœuvre              582.0
#
# [34923 rows x 5 columns]

# %%
data_new1["Population totale"].sum()
# Out:
# 67986317.0

# %%
data_new1.reset_index(inplace=True)
data_new1
# Out:
#         index  Code région      Nom de la région Code département  \
# 0           0         82.0           Rhône-Alpes               26
# 1           1         82.0           Rhône-Alpes               26
# 2           2         82.0           Rhône-Alpes               26
# 3           3         82.0           Rhône-Alpes               26
# 4           4         82.0           Rhône-Alpes               26
# ...       ...          ...                   ...              ...
# 34918  380115         26.0             Bourgogne               21
# 34919  382239         84.0  AUVERGNE-RHONE-ALPES               74
# 34920  391306         24.0                Centre               28
# 34921  398155         11.0         ILE-DE-FRANCE               77
# 34922  400517         52.0      Pays de la Loire               44
#
#                 Nom de la commune  Population totale
# 0            Ponet-et-Saint-Auban              124.0
# 1                Rochefort-Samson              931.0
# 2                   Rochefourchat                1.0
# 3           Saint-Dizier-en-Diois               37.0
# 4                     Saint-Roman              161.0
# ...                           ...                ...
# 34918  Saint-Germain-Source-Seine               28.0
# 34919                     Sevrier             4404.0
# 34920   Bleury - Saint-Symphorien             1366.0
# 34921      Moret Loing et Orvanne             7782.0
# 34922                   Bonnœuvre              582.0
#
# [34923 rows x 6 columns]

# %%
data_new1.groupby('Code région')['Population totale'].nunique().plot(kind='bar')
plt.show()

# %%
data_1_n
# Out:
#    Code département              département  Population totale
# 0                01                      Ain             659180
# 1                02                    Aisne             546527
# 2                03                   Allier             347035
# 3                04  Alpes-de-Haute-Provence             168381
# 4                05             Hautes-Alpes             145883
# ..              ...                      ...                ...
# 95               95               Val-d'Oise            1239262
# 96              971               Guadeloupe             396153
# 97              972               Martinique             377711
# 98              973                   Guyane             271124
# 99              974               La Réunion             863063
#
# [100 rows x 3 columns]

# %%
data_f = data_1_n.merge(data_new1, how="inner", on="Code département")
data_f
# Out:
#       Code département département  Population totale_x  index  Code région  \
# 0                   01         Ain               659180    671         82.0
# 1                   01         Ain               659180    672         82.0
# 2                   01         Ain               659180    673         82.0
# 3                   01         Ain               659180    674         82.0
# 4                   01         Ain               659180    675         82.0
# ...                ...         ...                  ...    ...          ...
# 34900              974  La Réunion               863063  34358          4.0
# 34901              974  La Réunion               863063  37960          4.0
# 34902              974  La Réunion               863063  48198          4.0
# 34903              974  La Réunion               863063  65879          4.0
# 34904              974  La Réunion               863063  68530          4.0
#
#       Nom de la région    Nom de la commune  Population totale_y
# 0          Rhône-Alpes             Ambutrix                656.0
# 1          Rhône-Alpes                  Bey                246.0
# 2          Rhône-Alpes           Chevillard                182.0
# 3          Rhône-Alpes  Dompierre-sur-Veyle               1171.0
# 4          Rhône-Alpes         Francheleins               1153.0
# ...                ...                  ...                  ...
# 34900       La Réunion          Les Avirons               9329.0
# 34901       La Réunion           Entre-Deux               6263.0
# 34902       LA REUNION            Le Tampon              77017.0
# 34903       LA REUNION            Saint-Leu              33440.0
# 34904       LA REUNION        L' Étang-Salé              14313.0
#
# [34905 rows x 8 columns]

# %%
data_f.reset_index(inplace=True)
data_f
# Out:
#        level_0 Code département département  Population totale_x  index  \
# 0            0               01         Ain               659180    671
# 1            1               01         Ain               659180    672
# 2            2               01         Ain               659180    673
# 3            3               01         Ain               659180    674
# 4            4               01         Ain               659180    675
# ...        ...              ...         ...                  ...    ...
# 34900    34900              974  La Réunion               863063  34358
# 34901    34901              974  La Réunion               863063  37960
# 34902    34902              974  La Réunion               863063  48198
# 34903    34903              974  La Réunion               863063  65879
# 34904    34904              974  La Réunion               863063  68530
#
#        Code région Nom de la région    Nom de la commune  Population totale_y
# 0             82.0      Rhône-Alpes             Ambutrix                656.0
# 1             82.0      Rhône-Alpes                  Bey                246.0
# 2             82.0      Rhône-Alpes           Chevillard                182.0
# 3             82.0      Rhône-Alpes  Dompierre-sur-Veyle               1171.0
# 4             82.0      Rhône-Alpes         Francheleins               1153.0
# ...            ...              ...                  ...                  ...
# 34900          4.0       La Réunion          Les Avirons               9329.0
# 34901          4.0       La Réunion           Entre-Deux               6263.0
# 34902          4.0       LA REUNION            Le Tampon              77017.0
# 34903          4.0       LA REUNION            Saint-Leu              33440.0
# 34904          4.0       LA REUNION        L' Étang-Salé              14313.0
#
# [34905 rows x 9 columns]

# %%
del data_f["Population totale_x"]
data_f
# Out:
#        level_0 Code département département  index  Code région  \
# 0            0               01         Ain    671         82.0
# 1            1               01         Ain    672         82.0
# 2            2               01         Ain    673         82.0
# 3            3               01         Ain    674         82.0
# 4            4               01         Ain    675         82.0
# ...        ...              ...         ...    ...          ...
# 34900    34900              974  La Réunion  34358          4.0
# 34901    34901              974  La Réunion  37960          4.0
# 34902    34902              974  La Réunion  48198          4.0
# 34903    34903              974  La Réunion  65879          4.0
# 34904    34904              974  La Réunion  68530          4.0
#
#       Nom de la région    Nom de la commune  Population totale_y
# 0          Rhône-Alpes             Ambutrix                656.0
# 1          Rhône-Alpes                  Bey                246.0
# 2          Rhône-Alpes           Chevillard                182.0
# 3          Rhône-Alpes  Dompierre-sur-Veyle               1171.0
# 4          Rhône-Alpes         Francheleins               1153.0
# ...                ...                  ...                  ...
# 34900       La Réunion          Les Avirons               9329.0
# 34901       La Réunion           Entre-Deux               6263.0
# 34902       LA REUNION            Le Tampon              77017.0
# 34903       LA REUNION            Saint-Leu              33440.0
# 34904       LA REUNION        L' Étang-Salé              14313.0
#
# [34905 rows x 8 columns]

# %%
del data_f["level_0"]
data_f
# Out:
#       Code département département  index  Code région Nom de la région  \
# 0                   01         Ain    671         82.0      Rhône-Alpes
# 1                   01         Ain    672         82.0      Rhône-Alpes
# 2                   01         Ain    673         82.0      Rhône-Alpes
# 3                   01         Ain    674         82.0      Rhône-Alpes
# 4                   01         Ain    675         82.0      Rhône-Alpes
# ...                ...         ...    ...          ...              ...
# 34900              974  La Réunion  34358          4.0       La Réunion
# 34901              974  La Réunion  37960          4.0       La Réunion
# 34902              974  La Réunion  48198          4.0       LA REUNION
# 34903              974  La Réunion  65879          4.0       LA REUNION
# 34904              974  La Réunion  68530          4.0       LA REUNION
#
#          Nom de la commune  Population totale_y
# 0                 Ambutrix                656.0
# 1                      Bey                246.0
# 2               Chevillard                182.0
# 3      Dompierre-sur-Veyle               1171.0
# 4             Francheleins               1153.0
# ...                    ...                  ...
# 34900          Les Avirons               9329.0
# 34901           Entre-Deux               6263.0
# 34902            Le Tampon              77017.0
# 34903            Saint-Leu              33440.0
# 34904        L' Étang-Salé              14313.0
#
# [34905 rows x 7 columns]

# %%
del data_f["index"]
data_f
# Out:
#       Code département département  Code région Nom de la région  \
# 0                   01         Ain         82.0      Rhône-Alpes
# 1                   01         Ain         82.0      Rhône-Alpes
# 2                   01         Ain         82.0      Rhône-Alpes
# 3                   01         Ain         82.0      Rhône-Alpes
# 4                   01         Ain         82.0      Rhône-Alpes
# ...                ...         ...          ...              ...
# 34900              974  La Réunion          4.0       La Réunion
# 34901              974  La Réunion          4.0       La Réunion
# 34902              974  La Réunion          4.0       LA REUNION
# 34903              974  La Réunion          4.0       LA REUNION
# 34904              974  La Réunion          4.0       LA REUNION
#
#          Nom de la commune  Population totale_y
# 0                 Ambutrix                656.0
# 1                      Bey                246.0
# 2               Chevillard                182.0
# 3      Dompierre-sur-Veyle               1171.0
# 4             Francheleins               1153.0
# ...                    ...                  ...
# 34900          Les Avirons               9329.0
# 34901           Entre-Deux               6263.0
# 34902            Le Tampon              77017.0
# 34903            Saint-Leu              33440.0
# 34904        L' Étang-Salé              14313.0
#
# [34905 rows x 6 columns]

# %%
data_f.rename(columns={'Population totale_y': 'Population totale'}, inplace=True)
data_f
# Out:
#       Code département département  Code région Nom de la région  \
# 0                   01         Ain         82.0      Rhône-Alpes
# 1                   01         Ain         82.0      Rhône-Alpes
# 2                   01         Ain         82.0      Rhône-Alpes
# 3                   01         Ain         82.0      Rhône-Alpes
# 4                   01         Ain         82.0      Rhône-Alpes
# ...                ...         ...          ...              ...
# 34900              974  La Réunion          4.0       La Réunion
# 34901              974  La Réunion          4.0       La Réunion
# 34902              974  La Réunion          4.0       LA REUNION
# 34903              974  La Réunion          4.0       LA REUNION
# 34904              974  La Réunion          4.0       LA REUNION
#
#          Nom de la commune  Population totale
# 0                 Ambutrix              656.0
# 1                      Bey              246.0
# 2               Chevillard              182.0
# 3      Dompierre-sur-Veyle             1171.0
# 4             Francheleins             1153.0
# ...                    ...                ...
# 34900          Les Avirons             9329.0
# 34901           Entre-Deux             6263.0
# 34902            Le Tampon            77017.0
# 34903            Saint-Leu            33440.0
# 34904        L' Étang-Salé            14313.0
#
# [34905 rows x 6 columns]

# %%
data_final = data_f.copy()
data_final
# Out:
#       Code département département  Code région Nom de la région  \
# 0                   01         Ain         82.0      Rhône-Alpes
# 1                   01         Ain         82.0      Rhône-Alpes
# 2                   01         Ain         82.0      Rhône-Alpes
# 3                   01         Ain         82.0      Rhône-Alpes
# 4                   01         Ain         82.0      Rhône-Alpes
# ...                ...         ...          ...              ...
# 34900              974  La Réunion          4.0       La Réunion
# 34901              974  La Réunion          4.0       La Réunion
# 34902              974  La Réunion          4.0       LA REUNION
# 34903              974  La Réunion          4.0       LA REUNION
# 34904              974  La Réunion          4.0       LA REUNION
#
#          Nom de la commune  Population totale
# 0                 Ambutrix              656.0
# 1                      Bey              246.0
# 2               Chevillard              182.0
# 3      Dompierre-sur-Veyle             1171.0
# 4             Francheleins             1153.0
# ...                    ...                ...
# 34900          Les Avirons             9329.0
# 34901           Entre-Deux             6263.0
# 34902            Le Tampon            77017.0
# 34903            Saint-Leu            33440.0
# 34904        L' Étang-Salé            14313.0
#
# [34905 rows x 6 columns]

# %%
data_final.isnull().value_counts()
# Out:
# Code département  département  Code région  Nom de la région  Nom de la commune  Population totale
# False             False        False        False             False              False                34905
# dtype: int64

# %%
data_final["Population totale"].sum()
# Out:
# 67750229.0

# %%
data_final.groupby('département')['Population totale'].nunique().plot(kind='bar')
plt.show()
